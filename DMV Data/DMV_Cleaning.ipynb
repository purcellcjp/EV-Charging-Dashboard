# %%
#import commands
import pandas as pd
import numpy as np
from pathlib import Path

# %%
#import csv files
alt_fuel_load = Path("Data/alt_fuel_stationsDC.csv")
alt_fuel_load2 = Path("Data/alt_fuel_stationsMD.csv")
alt_fuel_load3 = Path("Data/alt_fuel_stationsVA.csv")

# %%
# Read Data File and store into Pandas DataFrames
DC_fuel_data = pd.read_csv(alt_fuel_load)
MD_fuel_data = pd.read_csv(alt_fuel_load2)
Va_fuel_data = pd.read_csv(alt_fuel_load3)

# %%
# Print DC Data
DC_fuel_data.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                                   One Parking
# 1           ELEC  Florida Power & Light - Washington DC Office
# 2           ELEC                                Maritime Plaza
# 3           ELEC                        WASH HARBOUR STATION 1
# 4           ELEC               TOWER COMPANIES 1828 L ST NW #1
#
#             Street Address Intersection Directions        City State    ZIP  \
# 0           555 12th St NW                Level P3  Washington    DC  20004
# 1  801 Pennsylvania Ave NW               Suite 220  Washington    DC  20004
# 2             1201 M St SE                     NaN  Washington    DC  20003
# 3             3000 K St NW          Bottom of ramp  Washington    DC  20007
# 4             1828 L St NW   Closed on the weekend  Washington    DC  20036
#
#    Plus4 Station Phone Status Code  ... Funding Sources  \
# 0    NaN  202-393-0649           E  ...             NaN
# ...

# %%
# Print MD Data
MD_fuel_data.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                  ARUNDEL MILLS ELEMENT HOTELS
# 1           ELEC                              Municipal Garage
# 2           ELEC                                Bel Air Nissan
# 3           ELEC  Community College of Baltimore County (CCBC)
# 4           ELEC                                Younger Nissan
#
#       Street Address                 Intersection Directions         City  \
# 0     7522 Teague Rd  ChargePoint available for customer use      Hanover
# 1  200 N Holliday St                                     NaN    Baltimore
# 2    1506 Bel Air Rd                                     NaN      Bel Air
# 3   800 S Rolling Rd                                   Lot 8  Catonsville
# 4      7418 Grove Rd                                     NaN    Frederick
#
#   State    ZIP  Plus4 Station Phone Status Code  ... Funding Sources  \
# ...

# %%
# Print VA data
Va_fuel_data.head()
# Out:
#   Fuel Type Code                  Station Name              Street Address  \
# 0           ELEC                   Hotel Floyd               120 Wilson St
# 1           ELEC  Passport Nissan - Alexandria            150 S Pickett St
# 2           ELEC   Priority Nissan - Chantilly  14840 Stonecroft Center Ct
# 3           ELEC               Colonial Nissan                200 Myers Dr
# 4           ELEC        Brown's Fairfax Nissan          11010 Fairfax Blvd
#
#   Intersection Directions             City State    ZIP  Plus4 Station Phone  \
# 0                     NaN            Floyd    VA  24091    NaN  540-745-6080
# 1                     NaN       Alexandria    VA  22304    NaN  703-823-9000
# 2                     NaN        Chantilly    VA  20151    NaN  703-889-3700
# 3                     NaN  Charlottesville    VA  22901    NaN  434-978-3711
# 4                     NaN          Fairfax    VA  22030    NaN  703-591-8009
#
# ...

# %%
# Grab selected fields
DC_Fields = DC_fuel_data[['Fuel Type Code','Station Name', 'Street Address', 'Date Last Confirmed','Groups With Access Code', 'State', 'City', 'Open Date', 'ZIP', 'EV Connector Types', 'EV Pricing', 'Latitude', 'Longitude','Access Code']]
DC_Fields.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                                   One Parking
# 1           ELEC  Florida Power & Light - Washington DC Office
# 2           ELEC                                Maritime Plaza
# 3           ELEC                        WASH HARBOUR STATION 1
# 4           ELEC               TOWER COMPANIES 1828 L ST NW #1
#
#             Street Address Date Last Confirmed Groups With Access Code State  \
# 0           555 12th St NW          2023-08-10                  Public    DC
# 1  801 Pennsylvania Ave NW          2024-01-09                 Private    DC
# 2             1201 M St SE          2023-08-10                 Private    DC
# 3             3000 K St NW          2024-10-08                  Public    DC
# 4             1828 L St NW          2024-10-08                  Public    DC
#
#          City   Open Date    ZIP EV Connector Types     EV Pricing   Latitude  \
# ...

# %%
# add ID field
DC_Fields.loc[:, 'ID'] = range(1, len(DC_Fields) + 1)
DC_Fields.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                                   One Parking
# 1           ELEC  Florida Power & Light - Washington DC Office
# 2           ELEC                                Maritime Plaza
# 3           ELEC                        WASH HARBOUR STATION 1
# 4           ELEC               TOWER COMPANIES 1828 L ST NW #1
#
#             Street Address Date Last Confirmed Groups With Access Code State  \
# 0           555 12th St NW          2023-08-10                  Public    DC
# 1  801 Pennsylvania Ave NW          2024-01-09                 Private    DC
# 2             1201 M St SE          2023-08-10                 Private    DC
# 3             3000 K St NW          2024-10-08                  Public    DC
# 4             1828 L St NW          2024-10-08                  Public    DC
#
#          City   Open Date    ZIP EV Connector Types     EV Pricing   Latitude  \
# ...

# %%
# Grab selected fields
MD_Fields = MD_fuel_data[['Fuel Type Code','Station Name', 'Street Address','Date Last Confirmed','Groups With Access Code','State', 'City', 'Open Date', 'ZIP', 'EV Connector Types', 'EV Pricing', 'Latitude', 'Longitude','Access Code']]
MD_Fields.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                  ARUNDEL MILLS ELEMENT HOTELS
# 1           ELEC                              Municipal Garage
# 2           ELEC                                Bel Air Nissan
# 3           ELEC  Community College of Baltimore County (CCBC)
# 4           ELEC                                Younger Nissan
#
#       Street Address Date Last Confirmed           Groups With Access Code  \
# 0     7522 Teague Rd          2024-10-08  TEMPORARILY UNAVAILABLE (Public)
# 1  200 N Holliday St          2022-11-10                            Public
# 2    1506 Bel Air Rd          2024-02-12               Public - Call ahead
# 3   800 S Rolling Rd          2024-09-12                            Public
# 4      7418 Grove Rd          2024-02-12               Public - Call ahead
#
#   State         City   Open Date    ZIP        EV Connector Types EV Pricing  \
# ...

# %%
# Add ID field
MD_Fields.loc[:, 'ID'] = range(1, len(MD_Fields) + 1)
MD_Fields.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                  ARUNDEL MILLS ELEMENT HOTELS
# 1           ELEC                              Municipal Garage
# 2           ELEC                                Bel Air Nissan
# 3           ELEC  Community College of Baltimore County (CCBC)
# 4           ELEC                                Younger Nissan
#
#       Street Address Date Last Confirmed           Groups With Access Code  \
# 0     7522 Teague Rd          2024-10-08  TEMPORARILY UNAVAILABLE (Public)
# 1  200 N Holliday St          2022-11-10                            Public
# 2    1506 Bel Air Rd          2024-02-12               Public - Call ahead
# 3   800 S Rolling Rd          2024-09-12                            Public
# 4      7418 Grove Rd          2024-02-12               Public - Call ahead
#
#   State         City   Open Date    ZIP        EV Connector Types EV Pricing  \
# ...

# %%
# Grab Selected Fields
Va_fields = Va_fuel_data[['Fuel Type Code','Station Name', 'Street Address','Date Last Confirmed','Groups With Access Code', 'State', 'City', 'Open Date', 'ZIP', 'EV Connector Types', 'EV Pricing', 'Latitude', 'Longitude','Access Code']]
Va_fields.head()
# Out:
#   Fuel Type Code                  Station Name              Street Address  \
# 0           ELEC                   Hotel Floyd               120 Wilson St
# 1           ELEC  Passport Nissan - Alexandria            150 S Pickett St
# 2           ELEC   Priority Nissan - Chantilly  14840 Stonecroft Center Ct
# 3           ELEC               Colonial Nissan                200 Myers Dr
# 4           ELEC        Brown's Fairfax Nissan          11010 Fairfax Blvd
#
#   Date Last Confirmed Groups With Access Code State             City  \
# 0          2022-11-10                  Public    VA            Floyd
# 1          2024-02-12     Public - Call ahead    VA       Alexandria
# 2          2024-02-12     Public - Call ahead    VA        Chantilly
# 3          2024-02-12     Public - Call ahead    VA  Charlottesville
# 4          2024-02-12     Public - Call ahead    VA          Fairfax
#
#     Open Date    ZIP        EV Connector Types  \
# 0  2011-06-01  24091                     J1772
# ...

# %%
Va_fields.loc[:, 'ID'] = range(1, len(Va_fields) + 1)
Va_fields.head()
# Out:
#   Fuel Type Code                  Station Name              Street Address  \
# 0           ELEC                   Hotel Floyd               120 Wilson St
# 1           ELEC  Passport Nissan - Alexandria            150 S Pickett St
# 2           ELEC   Priority Nissan - Chantilly  14840 Stonecroft Center Ct
# 3           ELEC               Colonial Nissan                200 Myers Dr
# 4           ELEC        Brown's Fairfax Nissan          11010 Fairfax Blvd
#
#   Date Last Confirmed Groups With Access Code State             City  \
# 0          2022-11-10                  Public    VA            Floyd
# 1          2024-02-12     Public - Call ahead    VA       Alexandria
# 2          2024-02-12     Public - Call ahead    VA        Chantilly
# 3          2024-02-12     Public - Call ahead    VA  Charlottesville
# 4          2024-02-12     Public - Call ahead    VA          Fairfax
#
#     Open Date    ZIP        EV Connector Types  \
# 0  2011-06-01  24091                     J1772
# ...

# %%
# clean Data
DC_Fuel_cleaned = DC_Fields.dropna()
DC_Fuel_cleaned.head()
# Out:
#    Fuel Type Code                                Station Name  \
# 0            ELEC                                 One Parking
# 2            ELEC                              Maritime Plaza
# 6            ELEC                        Chevy Chase Pavilion
# 17           ELEC                    JBG - Fort Totten Square
# 27           ELEC  Washington Plaza Hotel - Tesla Destination
#
#            Street Address Date Last Confirmed Groups With Access Code State  \
# 0          555 12th St NW          2023-08-10                  Public    DC
# 2            1201 M St SE          2023-08-10                 Private    DC
# 6   5355 Wisconsin Ave NW          2023-08-10                  Public    DC
# 17        300 Riggs Rd NE          2024-10-08                  Public    DC
# 27       10 Thomas Cir NW          2022-10-06                  Public    DC
#
#           City   Open Date    ZIP EV Connector Types     EV Pricing  \
# ...

# %%
# clean Data
MD_Fuel_Cleaned = MD_Fields.dropna()
MD_Fuel_Cleaned.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 1           ELEC                              Municipal Garage
# 2           ELEC                                Bel Air Nissan
# 3           ELEC  Community College of Baltimore County (CCBC)
# 4           ELEC                                Younger Nissan
# 5           ELEC                               Criswell Nissan
#
#       Street Address Date Last Confirmed Groups With Access Code State  \
# 1  200 N Holliday St          2022-11-10                  Public    MD
# 2    1506 Bel Air Rd          2024-02-12     Public - Call ahead    MD
# 3   800 S Rolling Rd          2024-09-12                  Public    MD
# 4      7418 Grove Rd          2024-02-12     Public - Call ahead    MD
# 5  19574 Amaranth Dr          2024-02-12     Public - Call ahead    MD
#
#           City   Open Date    ZIP        EV Connector Types EV Pricing  \
# 1    Baltimore  2011-08-15  21202             J1772 NEMA520       Free
# ...

# %%
Va_Fuel_Cleaned = Va_fields.dropna()
Va_Fuel_Cleaned.head()
# Out:
#   Fuel Type Code                  Station Name              Street Address  \
# 0           ELEC                   Hotel Floyd               120 Wilson St
# 1           ELEC  Passport Nissan - Alexandria            150 S Pickett St
# 2           ELEC   Priority Nissan - Chantilly  14840 Stonecroft Center Ct
# 3           ELEC               Colonial Nissan                200 Myers Dr
# 4           ELEC        Brown's Fairfax Nissan          11010 Fairfax Blvd
#
#   Date Last Confirmed Groups With Access Code State             City  \
# 0          2022-11-10                  Public    VA            Floyd
# 1          2024-02-12     Public - Call ahead    VA       Alexandria
# 2          2024-02-12     Public - Call ahead    VA        Chantilly
# 3          2024-02-12     Public - Call ahead    VA  Charlottesville
# 4          2024-02-12     Public - Call ahead    VA          Fairfax
#
#     Open Date    ZIP        EV Connector Types  \
# 0  2011-06-01  24091                     J1772
# ...

# %%
# combine data tables
DMV_Fuel_Data = pd.concat([DC_Fuel_cleaned, MD_Fuel_Cleaned, Va_Fuel_Cleaned],  ignore_index=True)
DMV_Fuel_Data
# Out:
#      Fuel Type Code                                Station Name  \
# 0              ELEC                                 One Parking
# 1              ELEC                              Maritime Plaza
# 2              ELEC                        Chevy Chase Pavilion
# 3              ELEC                    JBG - Fort Totten Square
# 4              ELEC  Washington Plaza Hotel - Tesla Destination
# ...             ...                                         ...
# 1134           ELEC                               G&C Juice Bar
# 1135           ELEC             Chik-fil-A - Tesla Supercharger
# 1136           ELEC            Royal Farms - Tesla Supercharger
# 1137           ELEC            Royal Farms - Tesla Supercharger
# 1138           ELEC                   Wawa - Tesla Supercharger
#
#                   Street Address Date Last Confirmed Groups With Access Code  \
# 0                 555 12th St NW          2023-08-10                  Public
# ...

# %%
# fixing State field 
DMV_Fields = DMV_Fuel_Data [['State']]
unique_states = DMV_Fields['State'].unique()
print(unique_states)
# Out:
# ['DC' 'MD' 'VA']

# %%
DMV_Fuel_Data['State'] = DMV_Fuel_Data['State'].fillna('DC')
DMV_Fuel_Data.head()
# Out:
#   Fuel Type Code                                Station Name  \
# 0           ELEC                                 One Parking
# 1           ELEC                              Maritime Plaza
# 2           ELEC                        Chevy Chase Pavilion
# 3           ELEC                    JBG - Fort Totten Square
# 4           ELEC  Washington Plaza Hotel - Tesla Destination
#
#           Street Address Date Last Confirmed Groups With Access Code State  \
# 0         555 12th St NW          2023-08-10                  Public    DC
# 1           1201 M St SE          2023-08-10                 Private    DC
# 2  5355 Wisconsin Ave NW          2023-08-10                  Public    DC
# 3        300 Riggs Rd NE          2024-10-08                  Public    DC
# 4       10 Thomas Cir NW          2022-10-06                  Public    DC
#
#          City   Open Date    ZIP EV Connector Types     EV Pricing   Latitude  \
# ...

# %%
# Drop Null
DMV_Fuel_Cleaned = DMV_Fuel_Data.dropna()
DMV_Fuel_Cleaned
# Out:
#      Fuel Type Code                                Station Name  \
# 0              ELEC                                 One Parking
# 1              ELEC                              Maritime Plaza
# 2              ELEC                        Chevy Chase Pavilion
# 3              ELEC                    JBG - Fort Totten Square
# 4              ELEC  Washington Plaza Hotel - Tesla Destination
# ...             ...                                         ...
# 1134           ELEC                               G&C Juice Bar
# 1135           ELEC             Chik-fil-A - Tesla Supercharger
# 1136           ELEC            Royal Farms - Tesla Supercharger
# 1137           ELEC            Royal Farms - Tesla Supercharger
# 1138           ELEC                   Wawa - Tesla Supercharger
#
#                   Street Address Date Last Confirmed Groups With Access Code  \
# 0                 555 12th St NW          2023-08-10                  Public
# ...

# %%
# Re arrange the table
DMV_Fuel_Cleaned = DMV_Fuel_Data[['ID', 'Fuel Type Code','Station Name', 'Street Address', 'State', 'City', 'Open Date', 'ZIP', 'EV Connector Types', 'EV Pricing', 'Latitude', 'Longitude','Access Code']]
DMV_Fuel_Data.head()
# Out:
#   Fuel Type Code                                Station Name  \
# 0           ELEC                                 One Parking
# 1           ELEC                              Maritime Plaza
# 2           ELEC                        Chevy Chase Pavilion
# 3           ELEC                    JBG - Fort Totten Square
# 4           ELEC  Washington Plaza Hotel - Tesla Destination
#
#           Street Address Date Last Confirmed Groups With Access Code State  \
# 0         555 12th St NW          2023-08-10                  Public    DC
# 1           1201 M St SE          2023-08-10                 Private    DC
# 2  5355 Wisconsin Ave NW          2023-08-10                  Public    DC
# 3        300 Riggs Rd NE          2024-10-08                  Public    DC
# 4       10 Thomas Cir NW          2022-10-06                  Public    DC
#
#          City   Open Date    ZIP EV Connector Types     EV Pricing   Latitude  \
# ...

# %%
# create New CSV file 
output_path = Path("DMV_Fuel_Data.csv") 
DMV_Fuel_Data.to_csv(output_path, index=False)

# %%
#import commands
import pandas as pd
import numpy as np
from pathlib import Path

# %%
#import csv files
alt_fuel_load = Path("DMV Data CSV/alt_fuel_stationsDC.csv")
alt_fuel_load2 = Path("DMV Data CSV/alt_fuel_stationsMD.csv")
alt_fuel_load3 = Path("Dmv Data CSV/alt_fuel_stationsVA.csv")

# %%
# Read Data File and store into Pandas DataFrames
DC_fuel_data = pd.read_csv(alt_fuel_load)
MD_fuel_data = pd.read_csv(alt_fuel_load2)
Va_fuel_data = pd.read_csv(alt_fuel_load3)

# %%
# Print DC Data
DC_fuel_data.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                                   One Parking
# 1           ELEC  Florida Power & Light - Washington DC Office
# 2           ELEC                                Maritime Plaza
# 3           ELEC                        WASH HARBOUR STATION 1
# 4           ELEC               TOWER COMPANIES 1828 L ST NW #1
#
#             Street Address Intersection Directions        City State    ZIP  \
# 0           555 12th St NW                Level P3  Washington    DC  20004
# 1  801 Pennsylvania Ave NW               Suite 220  Washington    DC  20004
# 2             1201 M St SE                     NaN  Washington    DC  20003
# 3             3000 K St NW          Bottom of ramp  Washington    DC  20007
# 4             1828 L St NW   Closed on the weekend  Washington    DC  20036
#
#    Plus4 Station Phone Status Code  ... Funding Sources  \
# 0    NaN  202-393-0649           E  ...             NaN
# ...

# %%
# Print MD Data
MD_fuel_data.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                  ARUNDEL MILLS ELEMENT HOTELS
# 1           ELEC                              Municipal Garage
# 2           ELEC                                Bel Air Nissan
# 3           ELEC  Community College of Baltimore County (CCBC)
# 4           ELEC                                Younger Nissan
#
#       Street Address                 Intersection Directions         City  \
# 0     7522 Teague Rd  ChargePoint available for customer use      Hanover
# 1  200 N Holliday St                                     NaN    Baltimore
# 2    1506 Bel Air Rd                                     NaN      Bel Air
# 3   800 S Rolling Rd                                   Lot 8  Catonsville
# 4      7418 Grove Rd                                     NaN    Frederick
#
#   State    ZIP  Plus4 Station Phone Status Code  ... Funding Sources  \
# ...

# %%
# Print VA data
Va_fuel_data.head()
# Out:
#   Fuel Type Code                  Station Name              Street Address  \
# 0           ELEC                   Hotel Floyd               120 Wilson St
# 1           ELEC  Passport Nissan - Alexandria            150 S Pickett St
# 2           ELEC   Priority Nissan - Chantilly  14840 Stonecroft Center Ct
# 3           ELEC               Colonial Nissan                200 Myers Dr
# 4           ELEC        Brown's Fairfax Nissan          11010 Fairfax Blvd
#
#   Intersection Directions             City State    ZIP  Plus4 Station Phone  \
# 0                     NaN            Floyd    VA  24091    NaN  540-745-6080
# 1                     NaN       Alexandria    VA  22304    NaN  703-823-9000
# 2                     NaN        Chantilly    VA  20151    NaN  703-889-3700
# 3                     NaN  Charlottesville    VA  22901    NaN  434-978-3711
# 4                     NaN          Fairfax    VA  22030    NaN  703-591-8009
#
# ...

# %%
# Grab selected fields
DC_Fields = DC_fuel_data[['Fuel Type Code','Station Name', 'Street Address','State', 'City', 'ZIP', 'EV Connector Types', 'EV Pricing', 'Latitude', 'Longitude','Access Code']]
DC_Fields.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                                   One Parking
# 1           ELEC  Florida Power & Light - Washington DC Office
# 2           ELEC                                Maritime Plaza
# 3           ELEC                        WASH HARBOUR STATION 1
# 4           ELEC               TOWER COMPANIES 1828 L ST NW #1
#
#             Street Address State        City    ZIP EV Connector Types  \
# 0           555 12th St NW    DC  Washington  20004              J1772
# 1  801 Pennsylvania Ave NW    DC  Washington  20004              J1772
# 2             1201 M St SE    DC  Washington  20003              J1772
# 3             3000 K St NW    DC  Washington  20007              J1772
# 4             1828 L St NW    DC  Washington  20036              J1772
#
#       EV Pricing   Latitude  Longitude Access Code
# 0           Free  38.896703 -77.027621      public
# 1            NaN  38.894354 -77.023723     private
# ...

# %%
# Grab selected fields
MD_Fields = MD_fuel_data[['Fuel Type Code','Station Name', 'Street Address','State', 'City', 'ZIP', 'EV Connector Types', 'EV Pricing', 'Latitude', 'Longitude','Access Code']]
MD_Fields.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0           ELEC                  ARUNDEL MILLS ELEMENT HOTELS
# 1           ELEC                              Municipal Garage
# 2           ELEC                                Bel Air Nissan
# 3           ELEC  Community College of Baltimore County (CCBC)
# 4           ELEC                                Younger Nissan
#
#       Street Address State         City    ZIP        EV Connector Types  \
# 0     7522 Teague Rd    MD      Hanover  21076                   NEMA515
# 1  200 N Holliday St    MD    Baltimore  21202             J1772 NEMA520
# 2    1506 Bel Air Rd    MD      Bel Air  21014  CHADEMO J1772 J1772COMBO
# 3   800 S Rolling Rd    MD  Catonsville  21228                     J1772
# 4      7418 Grove Rd    MD    Frederick  21704  CHADEMO J1772 J1772COMBO
#
#   EV Pricing   Latitude  Longitude Access Code
# 0        NaN  39.155907 -76.717216      public
# 1       Free  39.291785 -76.610539      public
# ...

# %%
# Grab Selected Fields
Va_fields = Va_fuel_data[['Fuel Type Code','Station Name', 'Street Address', 'State', 'City', 'ZIP', 'EV Connector Types', 'EV Pricing', 'Latitude', 'Longitude','Access Code']]
Va_fields.head()
# Out:
#   Fuel Type Code                  Station Name              Street Address  \
# 0           ELEC                   Hotel Floyd               120 Wilson St
# 1           ELEC  Passport Nissan - Alexandria            150 S Pickett St
# 2           ELEC   Priority Nissan - Chantilly  14840 Stonecroft Center Ct
# 3           ELEC               Colonial Nissan                200 Myers Dr
# 4           ELEC        Brown's Fairfax Nissan          11010 Fairfax Blvd
#
#   State             City    ZIP        EV Connector Types  \
# 0    VA            Floyd  24091                     J1772
# 1    VA       Alexandria  22304  CHADEMO J1772 J1772COMBO
# 2    VA        Chantilly  20151             CHADEMO J1772
# 3    VA  Charlottesville  22901             CHADEMO J1772
# 4    VA          Fairfax  22030  CHADEMO J1772 J1772COMBO
#
#                             EV Pricing   Latitude  Longitude Access Code
# 0  Free for guests; $10 for non-guests  36.910575 -80.317360      public
# ...

# %%
# clean Data
DC_Fuel_cleaned = DC_Fields.dropna()
DC_Fuel_cleaned.head()
# Out:
#    Fuel Type Code                                Station Name  \
# 0            ELEC                                 One Parking
# 2            ELEC                              Maritime Plaza
# 6            ELEC                        Chevy Chase Pavilion
# 17           ELEC                    JBG - Fort Totten Square
# 27           ELEC  Washington Plaza Hotel - Tesla Destination
#
#            Street Address State        City    ZIP EV Connector Types  \
# 0          555 12th St NW    DC  Washington  20004              J1772
# 2            1201 M St SE    DC  Washington  20003              J1772
# 6   5355 Wisconsin Ave NW    DC  Washington  20015              J1772
# 17        300 Riggs Rd NE    DC  Washington  20011              J1772
# 27       10 Thomas Cir NW    DC  Washington  20005        J1772 TESLA
#
#        EV Pricing   Latitude  Longitude Access Code
# 0            Free  38.896703 -77.027621      public
# 2   $0.20 per kWh  38.875930 -76.989468     private
# ...

# %%
# clean Data
MD_Fuel_Cleaned = MD_Fields.dropna()
MD_Fuel_Cleaned.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 1           ELEC                              Municipal Garage
# 2           ELEC                                Bel Air Nissan
# 3           ELEC  Community College of Baltimore County (CCBC)
# 4           ELEC                                Younger Nissan
# 5           ELEC                               Criswell Nissan
#
#       Street Address State         City    ZIP        EV Connector Types  \
# 1  200 N Holliday St    MD    Baltimore  21202             J1772 NEMA520
# 2    1506 Bel Air Rd    MD      Bel Air  21014  CHADEMO J1772 J1772COMBO
# 3   800 S Rolling Rd    MD  Catonsville  21228                     J1772
# 4      7418 Grove Rd    MD    Frederick  21704  CHADEMO J1772 J1772COMBO
# 5  19574 Amaranth Dr    MD   Germantown  20874                     J1772
#
#   EV Pricing   Latitude  Longitude Access Code
# 1       Free  39.291785 -76.610539      public
# 2       Free  39.505900 -76.382380      public
# ...

# %%
Va_Fuel_Cleaned = Va_fields.dropna()
Va_Fuel_Cleaned.head()
# Out:
#   Fuel Type Code                  Station Name              Street Address  \
# 0           ELEC                   Hotel Floyd               120 Wilson St
# 1           ELEC  Passport Nissan - Alexandria            150 S Pickett St
# 2           ELEC   Priority Nissan - Chantilly  14840 Stonecroft Center Ct
# 3           ELEC               Colonial Nissan                200 Myers Dr
# 4           ELEC        Brown's Fairfax Nissan          11010 Fairfax Blvd
#
#   State             City    ZIP        EV Connector Types  \
# 0    VA            Floyd  24091                     J1772
# 1    VA       Alexandria  22304  CHADEMO J1772 J1772COMBO
# 2    VA        Chantilly  20151             CHADEMO J1772
# 3    VA  Charlottesville  22901             CHADEMO J1772
# 4    VA          Fairfax  22030  CHADEMO J1772 J1772COMBO
#
#                             EV Pricing   Latitude  Longitude Access Code
# 0  Free for guests; $10 for non-guests  36.910575 -80.317360      public
# ...

# %%
# combine data tables
DMV_Fuel_Data = pd.concat([DC_Fuel_cleaned, MD_Fuel_Cleaned, Va_Fuel_Cleaned],  ignore_index=True)
DMV_Fuel_Data
# Out:
#      Fuel Type Code                                Station Name  \
# 0              ELEC                                 One Parking
# 1              ELEC                              Maritime Plaza
# 2              ELEC                        Chevy Chase Pavilion
# 3              ELEC                    JBG - Fort Totten Square
# 4              ELEC  Washington Plaza Hotel - Tesla Destination
# ...             ...                                         ...
# 1135           ELEC                               G&C Juice Bar
# 1136           ELEC             Chik-fil-A - Tesla Supercharger
# 1137           ELEC            Royal Farms - Tesla Supercharger
# 1138           ELEC            Royal Farms - Tesla Supercharger
# 1139           ELEC                   Wawa - Tesla Supercharger
#
#                   Street Address              City    ZIP EV Connector Types  \
# 0                 555 12th St NW        Washington  20004              J1772
# ...

# %%
# fixing State field 
DMV_Fields = DMV_Fuel_Data [['State']]
unique_states = DMV_Fields['State'].unique()
print(unique_states)
# Out:
# [nan 'MD' 'VA']

# %%
DMV_Fuel_Data['State'] = DMV_Fuel_Data['State'].fillna('DC')
DMV_Fuel_Data.head()
# Out:
#   Fuel Type Code                                Station Name  \
# 0           ELEC                                 One Parking
# 1           ELEC                              Maritime Plaza
# 2           ELEC                        Chevy Chase Pavilion
# 3           ELEC                    JBG - Fort Totten Square
# 4           ELEC  Washington Plaza Hotel - Tesla Destination
#
#           Street Address        City    ZIP EV Connector Types     EV Pricing  \
# 0         555 12th St NW  Washington  20004              J1772           Free
# 1           1201 M St SE  Washington  20003              J1772  $0.20 per kWh
# 2  5355 Wisconsin Ave NW  Washington  20015              J1772           Free
# 3        300 Riggs Rd NE  Washington  20011              J1772           Free
# 4       10 Thomas Cir NW  Washington  20005        J1772 TESLA           Free
#
#     Latitude  Longitude Access Code State
# 0  38.896703 -77.027621      public    DC
# 1  38.875930 -76.989468     private    DC
# ...

# %%
# Drop Null
DMV_Fuel_Cleaned = DMV_Fuel_Data.dropna()
DMV_Fuel_Cleaned
# Out:
#      Fuel Type Code                                Station Name  \
# 0              ELEC                                 One Parking
# 1              ELEC                              Maritime Plaza
# 2              ELEC                        Chevy Chase Pavilion
# 3              ELEC                    JBG - Fort Totten Square
# 4              ELEC  Washington Plaza Hotel - Tesla Destination
# ...             ...                                         ...
# 1135           ELEC                               G&C Juice Bar
# 1136           ELEC             Chik-fil-A - Tesla Supercharger
# 1137           ELEC            Royal Farms - Tesla Supercharger
# 1138           ELEC            Royal Farms - Tesla Supercharger
# 1139           ELEC                   Wawa - Tesla Supercharger
#
#                   Street Address              City    ZIP EV Connector Types  \
# 0                 555 12th St NW        Washington  20004              J1772
# ...

# %%
# create New CSV file 
output_path = Path("DMV_Fuel_Cleaned.csv") 
DMV_Fuel_Cleaned.to_csv(output_path, index=False)
